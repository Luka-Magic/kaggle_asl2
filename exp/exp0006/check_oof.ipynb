# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
FOLD = 0

# %%
EXP_PATH = Path.cwd()
ROOT_DIR = EXP_PATH.parents[2]
exp_name = EXP_PATH.name
RAW_DATA_DIR = ROOT_DIR / 'data' / 'original_data'
DATA_DIR = ROOT_DIR / 'data' / 'kaggle_dataset' / 'irohith_tfrecords'
SAVE_DIR = ROOT_DIR / 'outputs' / exp_name / f'fold{FOLD}'
SAVE_DIR.mkdir(parents=True, exist_ok=True)

# %%
valid_result_df = pd.read_csv(SAVE_DIR / 'valid_result.csv')

# %%
valid_result_df = valid_result_df.fillna('').astype(str)

# %%
from Levenshtein import distance as Lev_distance
def calculate_N_D(s1, s2):
    l = len(s1)
    lvd = Lev_distance(s1, s2)
    return lvd, l
    
global_N, global_D = 0, 0
values = [calculate_N_D(target, predict) for target, predict in valid_result_df[['target', 'pred_epoch19']].values]
global_D += np.sum([x[0] for x in values])
global_N += np.sum([x[1] for x in values])

metric_value = np.clip((global_N - global_D) / global_N, a_min=0, a_max=1)

# %%
valid_result_df.columns[-1]
# Out:
# 'pred_epoch19'

# %%
from Levenshtein import distance as Lev_distance
def calculate_N_D(s1, s2):
    l = len(s1)
    lvd = Lev_distance(s1, s2)
    return lvd, l

scores = []
for target_string, predict_string in valid_result_df[['target', 'pred_epoch19']].values:
    D, N = calculate_N_D(target_string, predict_string)
    scores.append((N - D) / N)

score = np.mean(scores)

# %%
score
# Out:
# 0.8318715863596163

# %%
valid_result_df
# Out:
#                                target  \
# 0                       gladys guzman
# 1                       8780 old 13th
# 2      www.china-ycyb.com/arduinoprof
# 3              7642 south beulah road
# 4                    +682-45-4328-458
# ...                               ...
# 11284               7868 co road 3487
# 11285                kathleen peralta
# 11286                   custo-de-vida
# 11287                     alexis good
# 11288      7617 west winchester court
#
#                                              pred_epoch1  \
# 0                                                a1a8aha
# 1                                                   asaj
# 2      s@aj68a_a5jua17wa[jua8j_jh5[sa1asa18[8@a[j[j8,...
# 3                             a8a68asjsasasuasasa8asasas
# 4          a6a*5a85haxaha8a8a8a8a18a8a8a8aua8asaxa8adha8
# ...                                                  ...
# 11284  a8a8a8a8aha8haha848a8ma!8a8h8aha(aqa8uau8+a8sa...
# 11285  aqa8z8a8a8qaq8.a+q8om+o8q+8oqa:78a8a8a8as+8a8a...
# 11286                                                 ah
# 11287                                  ajajah&aj8[a8a8a8
# 11288  ama8as878m87as8s8a8sas8ma8s78s8a48a8a8sa8as8as...
#
#                                     pred_epoch2 pred_epoch3 pred_epoch4  \
# 0                                             a
# 1
# 2                            aaa8a8a8a8a8a8a8aa
# 3                                asaaa8a8aaaa8a
# 4                                          8888
# ...                                         ...         ...         ...
# 11284
# 11285
# 11286                                 aaaaaa8aa
# 11287                                        &a
# 11288  88a88a8a8a8a8a8a8a8a8a8a8a8a8aa8a8a8a8aa
#
#       pred_epoch5 pred_epoch6 pred_epoch7             pred_epoch8  \
# 0                                                          adysga
# 1                                                         8780l3
# 2                           w           w           w.hycbomaiopo
# 3                                       h           7642sothbelho
# 4                                       +        +682-45-4328-458
# ...           ...         ...         ...                     ...
# 11284                                   0              78680r0347
# 11285                                  ll            athleneralta
# 11286                                                  stotde2ida
# 11287                                                       lcsoo
# 11288                                      7617 6estwinchsteu cot
#
#                       pred_epoch9                 pred_epoch10  \
# 0                          gadsza                        adysa
# 1                        8780l 3h                    8780 ld 3
# 2          ww.ci-ycbom/ardduiopro     ww.chi-ycybom/arduinopro
# 3              7642sorth beulahro         7642 sorth beulah ro
# 4                +682-45-4328-458             +682-45-4328-458
# ...                           ...                          ...
# 11284                 78680r0a348                 7868 0roa347
# 11285               athlenperalta               kathlenperalta
# 11286                custode-vida                custotde-vida
# 11287                    lesjoood                    lexscoood
# 11288  7617 west winchoester cout  7617 west wincheste r court
#
#                      pred_epoch11                pred_epoch12  \
# 0                          adisza                       adsza
# 1                       8780 0d3h                8780 0old3 h
# 2         w.chi-ycbcom/arduinopro   ww.chi-ycybaom/arduinopro
# 3           7642 sourth beulthrot       7642 south beulah rod
# 4                +682-45-4328-458            +682-45-4328-458
# ...                           ...                         ...
# 11284                7868c0roa347                47868 0roa34
# 11285              athlen peralta            kathhlen peralta
# 11286               custo-de-vida               custo-de-vida
# 11287                      lexioo                      leiood
# 11288  7617 west wincheste rcourt  7617 west winchester court
#
#                      pred_epoch13                pred_epoch14  \
# 0                         gadysza                   gadys gza
# 1                     8780 old 3                   8780 ol2d3
# 2       ww.chi-ycyb.com/arduiopro   ww.chi-ycybtcom/ardinopro
# 3           7642 sorth beulah rod      7642 sorth beulah road
# 4                +682-45-4328-458            +682-45-4328-458
# ...                           ...                         ...
# 11284              7868 co roa347             7868 co roa3487
# 11285             kathlen peralta             kathlen peralta
# 11286               custo-de-vida               custo-de-vida
# 11287                    leis ood                 lexias good
# 11288  7617 west winchester court  7617 west winchester court
#
#                       pred_epoch15                pred_epoch16  \
# 0                          gadisza                    gadisgza
# 1                    8780 old a3 h              8780 molad 3th
# 2      ww.chi-ycybacom/oarduinopro  ww.chi-ycyb.com/arduinopro
# 3            7642 sorth beulah rod      7642 south beulah road
# 4                 +682-45-4328-458            +682-45-4328-458
# ...                            ...                         ...
# 11284               7868 co road34              7868 co road34
# 11285              pathlen peralta             kathlen peralta
# 11286                custo-de-vida               custo-de-vida
# 11287                    lexin ood                  lexis good
# 11288   7617 west winchester court  7617 west winchester court
#
#                      pred_epoch17                 pred_epoch18  \
# 0                       gadis zan                    gadis gza
# 1                  8780 nolda13 h              8780 old a 3 th
# 2      ww.chi-ycyb.com/arduinopro  www.chi-ycybcom/aruduinopro
# 3          7642 south beulah road      7642 south beultah road
# 4                +682-45-4328-458             +682-45-4328-458
# ...                           ...                          ...
# 11284            57868 co road347            7868 co road 3487
# 11285             kathlen peralta              kathlen peralta
# 11286               custo-de-vida                custo-de-vida
# 11287                   lexis.ood                   lexis good
# 11288  7617 west winchester court     7617 west winchester urt
#
#                      pred_epoch19
# 0                       gadys pan
# 1                   8780 old 3 th
# 2       ww.chi-ycybcom/arduinopro
# 3          7642 south beulah road
# 4                +682-45-4328-458
# ...                           ...
# 11284            7868 co road 347
# 11285             kathlen peralta
# 11286               custo-de-vida
# 11287                 lexia gaood
# 11288  7617 west winchester court
#
# [11289 rows x 20 columns]
